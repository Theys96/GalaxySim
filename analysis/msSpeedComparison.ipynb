# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
barneshut = pd.read_csv('compTime_barneshut.csv', sep=',')
ms = pd.read_csv('compTime_ms.csv', sep=',')

# %%
fig = plt.figure(figsize=(7, 4))
ax1 = fig.add_subplot(111)
ax1.set_xlabel("N")
ax1.set_ylabel("ms")
ax1.set_title("Computation time for different amounts of bodies N\nMost-Significant-Bodies Method")
ax1.scatter(ms.n,ms.ms, c='r', marker="x", label='Most-Significant-Bodies')
fig.savefig('ms_time_comparison1.pdf')
plt.show()

# %%
barneshut = pd.read_csv('compTime_barneshut.csv', sep=',')
ms = pd.read_csv('compTime_ms.csv', sep=',')

fig = plt.figure(figsize=(7, 4))
ax1 = fig.add_subplot(111)
ax1.set_xlabel("N")
ax1.set_ylabel("ms")
ax1.set_title("Computation time for different amounts of bodies N")
ax1.scatter(barneshut.n, barneshut.ms, c='b', marker="x", label='Barnes-Hut')
ax1.scatter(ms.n,ms.ms, c='r', marker="x", label='Most-Significant-Bodies')
ax1.legend()
fig.savefig('ms_time_comparison2.pdf')
plt.show()
