# %%
import numpy as np
import pandas as pd

spherical = pd.read_csv('spherical.csv', sep=',')
spiral = pd.read_csv('spiral.csv', sep=',')

# %%
import matplotlib.pyplot as pyplot

pyplot.scatter(spherical.x, spherical.y)
pyplot.show()

pyplot.scatter(spherical.theta, spherical.r)
pyplot.show()
